# %% [markdown]
# ### Import Library

# %%
import pandas as pd

# %%
Data = pd.read_csv('C:\sinus.txt') # Path menuju Folder atau nama file
Data
# Out:
#      X         y
# 0    1  0.841471
# 1    2  0.909297
# 2    3  0.141120
# 3    4 -0.756800
# 4    5 -0.958920
# 5    6 -0.279420
# 6    7  0.656987
# 7    8  0.989358
# 8    9  0.412118
# 9   10 -0.544020
# 10  11 -0.999990
# 11  12 -0.536570
# 12  13  0.420167
# 13  14  0.990607
# 14  15  0.650288
# 15  16 -0.287900
# 16  17 -0.961400
# 17  18 -0.750990
# 18  19  0.149877
# 19  20  0.912945

# %%
X = Data['X']
y = Data['y']

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       20 non-null     int64
#  1   y       20 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 452.0 bytes

# %%
Data.describe()
# Out:
#               X          y
# count  20.00000  20.000000
# mean   10.50000   0.049911
# std     5.91608   0.734392
# min     1.00000  -0.999990
# 25%     5.75000  -0.595762
# 50%    10.50000   0.145499
# 75%    15.25000   0.703108
# max    20.00000   0.990607

# %%
print(Data.head(5))
Data.tail(5)
# Out:
#    X         y           Z
# 0  1  0.841471    2.718282
# 1  2  0.909297    7.389056
# 2  3  0.141120   20.085537
# 3  4 -0.756800   54.598150
# 4  5 -0.958920  148.413159
#      X         y             Z
# 15  16 -0.287900  8.886111e+06
# 16  17 -0.961400  2.415495e+07
# 17  18 -0.750990  6.565997e+07
# 18  19  0.149877  1.784823e+08
# 19  20  0.912945  4.851652e+08

# %%
Data.columns
# Out:
# Index(['X', 'y'], dtype='object')

# %%
Data.values
# Out:
# array([[ 1.      ,  0.841471],
#        [ 2.      ,  0.909297],
#        [ 3.      ,  0.14112 ],
#        [ 4.      , -0.7568  ],
#        [ 5.      , -0.95892 ],
#        [ 6.      , -0.27942 ],
#        [ 7.      ,  0.656987],
#        [ 8.      ,  0.989358],
#        [ 9.      ,  0.412118],
#        [10.      , -0.54402 ],
#        [11.      , -0.99999 ],
#        [12.      , -0.53657 ],
#        [13.      ,  0.420167],
#        [14.      ,  0.990607],
#        [15.      ,  0.650288],
#        [16.      , -0.2879  ],
#        [17.      , -0.9614  ],
#        [18.      , -0.75099 ],
#        [19.      ,  0.149877],
#        [20.      ,  0.912945]])

# %%
import numpy as np

# %%
Z = np.exp(X)
Data['Z'] = Z
Data
# Out:
#      X         y             Z
# 0    1  0.841471  2.718282e+00
# 1    2  0.909297  7.389056e+00
# 2    3  0.141120  2.008554e+01
# 3    4 -0.756800  5.459815e+01
# 4    5 -0.958920  1.484132e+02
# 5    6 -0.279420  4.034288e+02
# 6    7  0.656987  1.096633e+03
# 7    8  0.989358  2.980958e+03
# 8    9  0.412118  8.103084e+03
# 9   10 -0.544020  2.202647e+04
# 10  11 -0.999990  5.987414e+04
# 11  12 -0.536570  1.627548e+05
# 12  13  0.420167  4.424134e+05
# 13  14  0.990607  1.202604e+06
# 14  15  0.650288  3.269017e+06
# 15  16 -0.287900  8.886111e+06
# 16  17 -0.961400  2.415495e+07
# 17  18 -0.750990  6.565997e+07
# 18  19  0.149877  1.784823e+08
# 19  20  0.912945  4.851652e+08

# %%
import matplotlib.pyplot as plt
plt.plot(X,y)
plt.show()

# %%
plt.plot(X,Z)
plt.show()

# %% [markdown]
# # Membuat Dataframe

# %%
A = np.linspace(0,10,100)
B = np.sin(A)
Data2 = pd.DataFrame(
    {"A":A,
     "B":B}
)
Data2
# Out:
#            A         B
# 0    0.00000  0.000000
# 1    0.10101  0.100838
# 2    0.20202  0.200649
# 3    0.30303  0.298414
# 4    0.40404  0.393137
# ..       ...       ...
# 95   9.59596 -0.170347
# 96   9.69697 -0.268843
# 97   9.79798 -0.364599
# 98   9.89899 -0.456637
# 99  10.00000 -0.544021
#
# [100 rows x 2 columns]

# %%
A = Data2['A']
B = Data2['B']
B.head()
# Out:
# 0    0.000000
# 1    0.100838
# 2    0.200649
# 3    0.298414
# 4    0.393137
# Name: B, dtype: float64
